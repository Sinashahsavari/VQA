# %%
import json
import pprint
import matplotlib.pyplot as plt

# %%
filebase = '/datasets/ee285f-public/VQA2017/'
filename = 'v2_OpenEnded_mscoco_test2015_questions.json'
filename = 'v2_mscoco_val2014_annotations.json'
filename = 'v2_OpenEnded_mscoco_test-dev2015_questions.json'
filename = 'v2_OpenEnded_mscoco_val2014_questions.json'
filename = 'v2_OpenEnded_mscoco_train2014_questions.json'
filename = 'v2_mscoco_train2014_annotations.json'
with open(filebase+filename,'r') as f:
    d = json.load(f)

print(d.keys())
print(d['info'])
pprint.pprint(d['annotations'][0])
# Out:
# dict_keys(['info', 'license', 'data_subtype', 'annotations', 'data_type'])
# {'description': 'This is v2.0 of the VQA dataset.', 'url': 'http://visualqa.org', 'version': '2.0', 'year': 2017, 'contributor': 'VQA Team', 'date_created': '2017-04-26 17:07:13'}
# {'answer_type': 'other',
#  'answers': [{'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1},
#              {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2},
#              {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3},
#              {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4},
#              {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5},
#              {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6},
#              {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7},
#              {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8},
#              {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9},
#              {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}],
#  'image_id': 458752,
#  'multiple_choice_answer': 'net',
#  'question_id': 458752000,
#  'question_type': 'what is this'}

# %%
filename = 'v2_OpenEnded_mscoco_train2014_questions.json'
with open(filebase+filename,'r') as f:
    d = json.load(f)

print(d.keys())
print(d['info'])
pprint.pprint(d['questions'][0])
# Out:
# dict_keys(['info', 'task_type', 'data_type', 'license', 'data_subtype', 'questions'])
# {'description': 'This is v2.0 of the VQA dataset.', 'url': 'http://visualqa.org', 'version': '2.0', 'year': 2017, 'contributor': 'VQA Team', 'date_created': '2017-04-26 17:07:13'}
# {'image_id': 458752,
#  'question': 'What is this photo taken looking through?',
#  'question_id': 458752000}

# %%
data_subtype = d['data_subtype']

# %%
image_id = d['questions'][0]["image_id"]
print(image_id)
image_filename = data_subtype + "/COCO_"+data_subtype+"_"+str(image_id).zfill(12)+".jpg"
img = plt.imread(filebase+image_filename)
plt.imshow(img)
# Out:
# 458752
